# %%
import pandas as pd

# %%
df = pd.read_csv('../data_adventureWorks/DimEmployee2.csv')
display(df.head(2))
# Out:
#    EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0            1               18.0                        14417807
# 1            2                7.0                       253022876
#
#    ParentEmployeeNationalIDAlternateKey  SalesTerritoryKey FirstName LastName  \
# 0                                   NaN                 11       Guy  Gilbert
# 1                                   NaN                 11     Kevin    Brown
#
#   MiddleName  NameStyle                         Title  ... BaseRate  \
# 0          R          0  Production Technician - WC60  ...  12.4500
# 1          F          0           Marketing Assistant  ...  13.4615
#
#   VacationHours SickLeaveHours CurrentFlag SalesPersonFlag DepartmentName  \
# 0            21             30           1               0     Production
# 1            42             41           1               0      Marketing
#
#     StartDate EndDate   Status  \
# 0  2006-01-28     NaN  Current
# ...

# %%
df['EmployeeKey'].notna().sum()
# Out:
# 296
