# %%
import pandas as pd

# %%
df = pd.read_csv('../data_adventureWorks/DimReseller2.csv')
display(df.head(2))
# Out:
#    ResellerKey  GeographyKey ResellerAlternateKey         Phone  \
# 0            1           637           AW00000001  245-555-0173
# 1            2           635           AW00000002  170-555-0127
#
#            BusinessType        ResellerName  NumberEmployees OrderFrequency  \
# 0  Value Added Reseller        A Bike Store                2              S
# 1   Specialty Bike Shop  Progressive Sports               10              A
#
#    OrderMonth  FirstOrderYear  LastOrderYear ProductLine        AddressLine1  \
# 0         5.0          2011.0         2011.0        Road  2251 Elliot Avenue
# 1         5.0          2012.0         2013.0    Mountain    3207 S Grady Way
#
#   AddressLine2  AnnualSales                BankName  MinPaymentType  \
# 0          NaN     300000.0      International Bank             NaN
# 1          NaN     800000.0  International Security             1.0
#
#    MinPaymentAmount  AnnualRevenue  YearOpened
# 0               NaN        30000.0        1974
# ...

# %%
df['ResellerKey'].notna().sum()
# Out:
# 701
