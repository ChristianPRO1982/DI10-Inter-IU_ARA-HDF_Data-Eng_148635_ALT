# %%
from pathlib import Path

path = Path("../data_adventureWorks/DimEmployee2.csv")

with path.open("rb") as f:
    raw = f.read(4096)

print(raw[:200])  # bytes (permet de repérer BOM, séparateur, etc.)

with path.open("r", encoding="utf-8", errors="replace") as f:
    for i in range(1, 21):
        line = f.readline()
        print(f"{i:02d}: {line.rstrip()}")
# Out:
# b'EmployeeKey,ParentEmployeeKey,EmployeeNationalIDAlternateKey,ParentEmployeeNationalIDAlternateKey,SalesTerritoryKey,FirstName,LastName,MiddleName,NameStyle,Title,HireDate,BirthDate,LoginID,EmailAddres'
# 01: EmployeeKey,ParentEmployeeKey,EmployeeNationalIDAlternateKey,ParentEmployeeNationalIDAlternateKey,SalesTerritoryKey,FirstName,LastName,MiddleName,NameStyle,Title,HireDate,BirthDate,LoginID,EmailAddress,Phone,MaritalStatus,EmergencyContactName,EmergencyContactPhone,SalariedFlag,Gender,PayFrequency,BaseRate,VacationHours,SickLeaveHours,CurrentFlag,SalesPersonFlag,DepartmentName,StartDate,EndDate,Status,EmployeePhoto
# 02: 1,18,14417807,,11,Guy,Gilbert,R,0,Production Technician - WC60,2006-01-28,1981-11-12,adventure-works\guy1,guy1@adventure-works.com,320-555-0195,M,Guy Gilbert,320-555-0195,0,M,1,12.4500,21,30,1,0,Production,2006-01-28,,Current,...
# 03: 2,7,253022876,,11,Kevin,Brown,F,0,Marketing Assistant,2006-08-26,1986-12-01,adventure-works\kevin0,kevin0@adventure-works.com,150-555-0189,S,Kevin Brown,150-555-0189,0,M,2,13.4615,42,41,1,0,Marketing,2006-08-26,,Current,...
# 04: 3,14,509647174,,11,Roberto,Tamburello,,0,Engineering Manager,2007-06-11,1974-06-12,adventure-works\roberto0,roberto0@adventure-works.com,212-555-0187,M,Roberto Tamburello,212-555-0187,1,M,2,43.2692,2,21,1,0,Engineering,2007-06-11,,Current,...
# 05: 4,3,112457891,,11,Rob,Walters,,0,Senior Tool Designer,2007-07-05,1974-07-23,adventure-works\rob0,rob0@adventure-works.com,612-555-0100,S,Rob Walters,612-555-0100,0,M,2,29.8462,48,80,1,0,Tool Design,2007-07-05,2009-12-28,,...
# 06: 5,3,112457891,,11,Rob,Walters,,0,Senior Tool Designer,2007-07-05,1974-07-23,adventure-works\rob0,rob0@adventure-works.com,612-555-0100,S,Rob Walters,612-555-0100,0,M,2,29.8462,48,80,1,0,Tool Design,2009-12-28,,Current,...
# 07: 6,267,480168528,,11,Thierry,D'Hers,B,0,Tool Designer,2007-07-11,1959-02-26,adventure-works\thierry0,thierry0@adventure-works.com,168-555-0183,M,Thierry D'Hers,168-555-0183,0,M,2,25.0000,9,24,1,0,Tool Design,2007-07-11,,Current,...
# 08: 7,112,24756624,,11,David,Bradley,M,0,Marketing Manager,2007-07-20,1974-10-17,adventure-works\david0,david0@adventure-works.com,913-555-0172,S,David Bradley,913-555-0172,1,M,2,37.5000,40,40,1,0,Marketing,2007-07-20,2009-02-11,,...
# 09: 8,112,24756624,,11,David,Bradley,M,0,Marketing Manager,2007-07-20,1974-10-17,adventure-works\david0,david0@adventure-works.com,913-555-0172,S,David Bradley,913-555-0172,1,M,2,37.5000,40,40,1,0,Marketing,2009-02-12,,Current,...
# 10: 9,23,309738752,,11,JoLynn,Dobney,M,0,Production Supervisor - WC60,2007-07-26,1955-08-16,adventure-works\jolynn0,jolynn0@adventure-works.com,903-555-0145,S,JoLynn Dobney,903-555-0145,0,F,2,25.0000,82,61,1,0,Production,2007-07-26,,Current,...
# 11: 10,189,690627818,,11,Ruth,Ellerbrock,Ann,0,Production Technician - WC10,2007-08-06,1956-01-03,adventure-works\ruth0,ruth0@adventure-works.com,145-555-0130,M,Ruth Ellerbrock,145-555-0130,0,F,1,13.4500,83,61,1,0,Production,2007-08-06,,Current,...
# 12: 11,3,695256908,,11,Gail,Erickson,A,0,Design Engineer,2007-08-06,1952-04-27,adventure-works\gail0,gail0@adventure-works.com,849-555-0139,M,Gail Erickson,849-555-0139,1,F,2,32.6923,5,22,1,0,Engineering,2007-08-06,,Current,...
# 13: 12,189,912265825,,11,Barry,Johnson,K,0,Production Technician - WC10,2007-08-07,1955-10-25,adventure-works\barry0,barry0@adventure-works.com,206-555-0180,S,Barry Johnson,206-555-0180,0,M,1,13.4500,88,64,1,0,Production,2007-08-07,,Current,...
# 14: 13,3,998320692,,11,Jossef,Goldberg,H,0,Design Engineer,2007-08-24,1958-10-09,adventure-works\jossef0,jossef0@adventure-works.com,122-555-0189,M,Jossef Goldberg,122-555-0189,1,M,2,32.6923,6,23,1,0,Engineering,2007-08-24,,Current,...
# 15: 14,112,245797967,,11,Terri,Duffy,Lee,0,Vice President of Engineering,2007-08-31,1971-03-01,adventure-works\terri0,terri0@adventure-works.com,819-555-0175,S,Terri Duffy,819-555-0175,1,F,2,63.4615,1,20,1,0,Engineering,2007-08-31,,Current,...
# 16: 15,189,844973625,,11,Sidney,Higa,M,0,Production Technician - WC10,2007-09-02,1956-03-30,adventure-works\sidney0,sidney0@adventure-works.com,424-555-0189,M,Sidney Higa,424-555-0189,0,M,1,13.4500,84,62,1,0,Production,2007-09-02,,Current,...
# 17: 16,23,233069302,,11,Taylor,Maxwell,R,0,Production Supervisor - WC50,2007-09-08,1955-10-31,adventure-works\taylor0,taylor0@adventure-works.com,508-555-0165,M,Taylor Maxwell,508-555-0165,0,M,2,25.0000,79,59,1,0,Production,2007-09-08,,Current,...
# 18: 17,189,132674823,,11,Jeffrey,Ford,L,0,Production Technician - WC10,2007-09-20,1956-02-09,adventure-works\jeffrey0,jeffrey0@adventure-works.com,984-555-0185,S,Jeffrey Ford,984-555-0185,0,M,1,13.4500,85,62,1,0,Production,2007-09-20,,Current,...
# 19: 18,23,446466105,,11,Jo,Brown,A,0,Production Supervisor - WC60,2007-09-27,1956-05-08,adventure-works\jo0,jo0@adventure-works.com,632-555-0129,S,Jo Brown,632-555-0129,0,F,2,25.0000,80,60,1,0,Production,2007-09-27,,Current,...
# 20: 19,189,565090917,,11,Doris,Hartwig,M,0,Production Technician - WC10,2007-10-09,1955-11-03,adventure-works\doris0,doris0@adventure-works.com,328-555-0150,M,Doris Hartwig,328-555-0150,0,F,1,13.4500,86,63,1,0,Production,2007-10-09,,Current,...

# %%
seps = ["|"]
with path.open("r", encoding="utf-8", errors="replace") as f:
    lines = [f.readline() for _ in range(20)]

for s in seps:
    counts = [ln.count(s) for ln in lines if ln]
    print(s, "min/avg/max =", min(counts), sum(counts)/len(counts), max(counts))
# Out:
# | min/avg/max = 0 0.0 0

# %%
import pandas as pd

df_head = pd.read_csv(
    path,
    sep=None,            # détection automatique (python engine)
    engine="python",
    on_bad_lines="warn", # affiche les lignes problématiques
    nrows=50,
)
print(df_head.shape)
display(df_head.head())
# Out:
# (50, 31)
#    EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0            1                 18                        14417807
# 1            2                  7                       253022876
# 2            3                 14                       509647174
# 3            4                  3                       112457891
# 4            5                  3                       112457891
#
#    ParentEmployeeNationalIDAlternateKey  SalesTerritoryKey FirstName  \
# 0                                   NaN                 11       Guy
# 1                                   NaN                 11     Kevin
# 2                                   NaN                 11   Roberto
# 3                                   NaN                 11       Rob
# 4                                   NaN                 11       Rob
#
#      LastName MiddleName  NameStyle                         Title  ...  \
# 0     Gilbert          R          0  Production Technician - WC60  ...
# 1       Brown          F          0           Marketing Assistant  ...
# 2  Tamburello        NaN          0           Engineering Manager  ...
# 3     Walters        NaN          0          Senior Tool Designer  ...
# 4     Walters        NaN          0          Senior Tool Designer  ...
#
#   BaseRate VacationHours SickLeaveHours CurrentFlag SalesPersonFlag  \
# 0  12.4500            21             30           1               0
# 1  13.4615            42             41           1               0
# 2  43.2692             2             21           1               0
# 3  29.8462            48             80           1               0
# 4  29.8462            48             80           1               0
#
#   DepartmentName   StartDate     EndDate   Status  \
# 0     Production  2006-01-28         NaN  Current
# 1      Marketing  2006-08-26         NaN  Current
# 2    Engineering  2007-06-11         NaN  Current
# 3    Tool Design  2007-07-05  2009-12-28      NaN
# 4    Tool Design  2009-12-28         NaN  Current
#
#                                        EmployeePhoto
# 0  FFD8FFE000104A46494600010101004800480000FFED00...
# 1  FFD8FFE000104A46494600010101004800480000FFED02...
# 2  FFD8FFE000104A4649460001010100FA00FA0000FFED01...
# 3  FFD8FFE000104A46494600010101004800480000FFED01...
# 4  FFD8FFE000104A46494600010101004800480000FFED01...
#
# [5 rows x 31 columns]

# %%
import sweetviz as sv

report = sv.analyze(df_head)
report.show_html("EDA_DimEmployee.html")
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report EDA_DimEmployee.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
